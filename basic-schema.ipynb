# %%
import os
from dotenv import load_dotenv,find_dotenv
load_dotenv(find_dotenv())
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
model=ChatOpenAI(
     base_url="https://api.groq.com/openai/v1",
    model="openai/gpt-oss-120b",
    api_key=os.getenv("Free_API_KEY"),
    temperature=0.0,
)

# %%
response=model.invoke("First women to win nobel prize?")
print(response.content)
# Out:
# c:\Users\pande\AppData\Local\pypoetry\Cache\virtualenvs\004-long-text-summarizer-LCt4uGY7-py3.11\Lib\site-packages\langsmith\client.py:241: LangSmithMissingAPIKeyWarning: API key must be provided when using hosted LangSmith API
#   warnings.warn(
# The first woman ever to receive a Nobel Prize was **Marie Curie**.
#
# - **Year:** 1903
# - **Category:** Nobel Prize in Physics (shared with her husband Pierre Curie and Henri Becquerel) for their pioneering work on radioactivity.
#
# She later became the first person—and the only woman—to win a second Nobel Prize, this time in **Chemistry** in 1911, for her discovery of the elements radium and polonium and her work on the chemistry of radioactive substances.
# Failed to multipart ingest runs: langsmith.utils.LangSmithAuthError: Authentication failed for https://api.smith.langchain.com/runs/multipart. HTTPError('401 Client Error: Unauthorized for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Unauthorized"}\n')trace=a328eb94-396d-445b-840f-298836246fba,id=a328eb94-396d-445b-840f-298836246fba
# Failed to multipart ingest runs: langsmith.utils.LangSmithAuthError: Authentication failed for https://api.smith.langchain.com/runs/multipart. HTTPError('401 Client Error: Unauthorized for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Unauthorized"}\n')trace=a328eb94-396d-445b-840f-298836246fba,id=a328eb94-396d-445b-840f-298836246fba
